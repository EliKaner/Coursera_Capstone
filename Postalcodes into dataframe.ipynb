# %% [markdown]
# Hello
# This notebook is for my project for the
#  **Applied Data Science Capstone**
# I don't know yet what I am going to do in it.
# I am going ahead, and I will see.

# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import urllib

# %%
html_doc = 'e:List of postal codes of Canada_ M - Wikipedia.html'
with open(html_doc, "r", encoding='utf-8') as f:
     wiki_text= f.read()

# %%
soup = BeautifulSoup(wiki_text, 'html.parser')
soup.title
# Out:
# <title>List of postal codes of Canada: M - Wikipedia</title>

# %% [markdown]
# find the number of rows in the postal codes table

# %%
table = soup.find_all('table')[0] 
num_of_rows=0
for row in table.find_all('tr'):
    num_of_rows+=1

# %% [markdown]
# ### read the table into dataframe
# in the ROW loop, we are going over all the rows in the html talbe and put it into array named data
# in the COLUMN loop, we are going over the columns: PostalCode, Borough, Neighborhood
# Now, for each row, we are checking duplicated and Not assigned values and treat then

# %%
data= [None, None, None]
toronto_df = pd.DataFrame(columns=['PostalCode','Borough', 'Neighborhood'], index=np.arange(0, num_of_rows+1)) 
row_marker = 0
for row in table.find_all('tr'):    
    column_marker = 0
    duplicate_postal=False
    columns = row.find_all('td')           
    for column in columns:                
        data[column_marker]=column.get_text().replace( '\n', '')                                  
        column_marker+=1  
    if data[2] =='Not assigned\n':
       data[2] = data[1] 
    if data[1] != 'Not assigned':          
       #find duplicate        
       #for num_row in np.arange(0, row_marker):
           #print('in loop=', num_row, toronto_df.iat[num_row, 0], df[0])
       if toronto_df.iat[row_marker-1, 0]== data[0]:
          toronto_df.iat[row_marker-1, 2] = toronto_df.iat[row_marker-1, 2] + ', ' + data[2]
              #print('=', num_row, toronto_df.iat[num_row, 0], df[0], toronto_df.iat[num_row, 2])       
       else:
           toronto_df.iat[row_marker, 0]= data[0] 
           toronto_df.iat[row_marker, 1]= data[1] 
           toronto_df.iat[row_marker, 2]= data[2]  
           row_marker +=1
                             
toronto_df.dropna(inplace=True)
toronto_df.sort_values(by=['PostalCode'])
toronto_df
# Out:
#     PostalCode           Borough  \
# 1          M1B       Scarborough
# 2          M1C       Scarborough
# 3          M1E       Scarborough
# 4          M1G       Scarborough
# 5          M1H       Scarborough
# 6          M1J       Scarborough
# 7          M1K       Scarborough
# 8          M1L       Scarborough
# 9          M1M       Scarborough
# 10         M1N       Scarborough
# 11         M1P       Scarborough
# 12         M1R       Scarborough
# 13         M1S       Scarborough
# 14         M1T       Scarborough
# 15         M1V       Scarborough
# 16         M1W       Scarborough
# 17         M1X       Scarborough
# 18         M2H        North York
# 19         M2J        North York
# 20         M2K        North York
# 21         M2L        North York
# 22         M2M        North York
# 23         M2N        North York
# 24         M2P        North York
# 25         M2R        North York
# 26         M3A        North York
# 27         M3B        North York
# 28         M3C        North York
# 29         M3H        North York
# 30         M3J        North York
# ..         ...               ...
# 74         M6C              York
# 75         M6E              York
# 76         M6G  Downtown Toronto
# 77         M6H      West Toronto
# 78         M6J      West Toronto
# 79         M6K      West Toronto
# 80         M6L        North York
# 81         M6M              York
# 82         M6N              York
# 83         M6P      West Toronto
# 84         M6R      West Toronto
# 85         M6S      West Toronto
# 86         M7A      Queen's Park
# 87         M7R       Mississauga
# 88         M7Y      East Toronto
# 89         M8V         Etobicoke
# 90         M8W         Etobicoke
# 91         M8X         Etobicoke
# 92         M8Y         Etobicoke
# 93         M8Z         Etobicoke
# 94         M9A         Etobicoke
# 95         M9B         Etobicoke
# 96         M9C         Etobicoke
# 97         M9L        North York
# 98         M9M        North York
# 99         M9N              York
# 100        M9P         Etobicoke
# 101        M9R         Etobicoke
# 102        M9V         Etobicoke
# 103        M9W         Etobicoke
#
#                                           Neighborhood
# 1                                       Rouge, Malvern
# 2               Rouge Hill, Port Union, Highland Creek
# 3                    West Hill, Morningside, Guildwood
# 4                                               Woburn
# 5                                            Cedarbrae
# 6                                  Scarborough Village
# 7          Kennedy Park, Ionview, East Birchmount Park
# 8                      Oakridge, Golden Mile, Clairlea
# 9      Scarborough Village West, Cliffside, Cliffcrest
# 10                         Cliffside West, Birch Cliff
# 11   Wexford Heights, Scarborough Town Centre, Dors...
# 12                                   Wexford, Maryvale
# 13                                           Agincourt
# 14             Tam O'Shanter, Sullivan, Clarks Corners
# 15   Steeles East, Milliken, L'Amoreaux East, Aginc...
# 16                       Steeles West, L'Amoreaux West
# 17                                         Upper Rouge
# 18                                   Hillcrest Village
# 19                        Oriole, Henry Farm, Fairview
# 20                                     Bayview Village
# 21                            York Mills, Silver Hills
# 22                             Willowdale, Newtonbrook
# 23                                    Willowdale South
# 24                                     York Mills West
# 25                                     Willowdale West
# 26                                           Parkwoods
# 27                                     Don Mills North
# 28                    Flemingdon Park, Don Mills South
# 29     Wilson Heights, Downsview North, Bathurst Manor
# 30                     York University, Northwood Park
# ..                                                 ...
# 74                                  Humewood-Cedarvale
# 75                                 Caledonia-Fairbanks
# 76                                            Christie
# 77                        Dufferin, Dovercourt Village
# 78                            Trinity, Little Portugal
# 79        Parkdale Village, Exhibition Place, Brockton
# 80            Upwood Park, North Park, Maple Leaf Park
# 81      Silverthorn, Mount Dennis, Keelesdale, Del Ray
# 82                       The Junction North, Runnymede
# 83                       The Junction South, High Park
# 84                              Roncesvalles, Parkdale
# 85                                  Swansea, Runnymede
# 86                                        Not assigned
# 87               Canada Post Gateway Processing Centre
# 88   Business Reply Mail Processing Centre 969 Eastern
# 89        New Toronto, Mimico South, Humber Bay Shores
# 90                              Long Branch, Alderwood
# 91       The Kingsway, Old Mill North, Montgomery Road
# 92   The Queensway East, Sunnylea, Royal York South...
# 93   The Queensway West, South of Bloor, Royal York...
# 94                                    Islington Avenue
# 95   West Deane Park, Princess Gardens, Martin Grov...
# 96   Old Burnhamthorpe, Markland Wood, Eringate, Bl...
# 97                                       Humber Summit
# 98                                    Humberlea, Emery
# 99                                              Weston
# 100                                          Westmount
# 101  St. Phillips, Richview Gardens, Martin Grove G...
# 102  Thistletown, South Steeles, Silverstone, Mount...
# 103                                          Northwest
#
# [103 rows x 3 columns]

# %%
toronto_df.shape
# Out:
# (103, 3)
